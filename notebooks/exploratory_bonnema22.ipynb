# %%
import pandas as pd
import geopandas as gpd
import codebase

# %%
sw_raw = pd.read_csv('/global/scratch/users/ann_scheliga/aux_dam_datasets/SurfaceArea.csv')

# %%
lakes_shp = gpd.read_file('/global/scratch/users/ann_scheliga/aux_dam_datasets/HydroLAKES_points_v10_shp/HydroLAKES_points_v10.shp')

# %%
res_shp = codebase.load_data.load_GRanD()
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /global/home/users/ann_scheliga/.conda/envs/rioxarray_env/share/proj failed

# %%
res_shp['GRAND_ID']
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 7245    7316
# 7246    7317
# 7247    7318
# 7248    7319
# 7249    7320
# Name: GRAND_ID, Length: 7250, dtype: int64

# %%
sw_raw
# Out:
#         HyLake_ID  2017/01/01/16  2017/02/01/16  2017/03/01/16  2017/04/01/17  \
# 0          101007       1.098453       1.026939       1.026939       1.016045
# 1          103202       0.569452       0.675398       0.231759       0.457245
# 2           98394       0.973204       0.941400       1.005008       0.998644
# 3          100731       0.796095       0.776684       0.789623       0.737840
# 4          107639       0.968339       0.816174       0.567171       0.954505
# ...           ...            ...            ...            ...            ...
# 160596          2       0.000000       0.000000       0.000000       0.750637
# 160597          3       0.000000       0.000000       0.000000      64.605020
# 160598          4       0.000000       0.000000    1036.813448   11879.519426
# 160599         10       0.000000       0.000000       0.000000   14743.706462
# 160600         13       0.000000       0.000000    7142.078058    6484.620001
#
# ...
