# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
datadir = '/global/scratch/users/ann_scheliga/yao2023_sat_lake_decline/'

# %%
eAral_results = pd.read_csv(datadir + 'results/ID82Large_aral_sea_East30m_GEE1992_2020_monthlyVolume_Poly.csv')
eAral_results.plot(kind = 'scatter',y='Mean_Levels', x= 'LakeArea')
# Out:
# <Axes: xlabel='LakeArea', ylabel='Mean_Levels'>

# %%
wAral_results = pd.read_csv(datadir + 'results/ID82Large_aral_sea_West30m_GEE1992_2020_monthlyVolume_Poly.csv')
wAral_results.plot(kind = 'scatter',y='Mean_Levels', x= 'LakeArea')
# Out:
# <Axes: xlabel='LakeArea', ylabel='Mean_Levels'>

# %%
icesat_results = pd.read_csv(datadir + 'results/ICESat_waterlevels9900051.txt', header=6, sep = ' ',skipinitialspace = True)
icesat_results
# Out:
#           date  level_std  level_medium  level_mean  numpoints
# 0   2018-12-29   0.028663   -215.188268   -215.1870         71
# 1   2018-12-29   0.021160   -215.182385   -215.1760         13
# 2   2019-01-08   0.066612   -215.158955   -215.1420         44
# 3   2019-01-08   0.055772   -215.101857   -215.1100          7
# 4   2019-04-09   0.018222   -212.470061   -212.4700        442
# 5   2019-04-09   0.019840   -212.447448   -212.4460        145
# 6   2019-10-07   0.026176   -212.436702   -212.4360         94
# 7   2019-10-07   0.026335   -212.413197   -212.4130        476
# 8   2020-03-27   0.015856   -209.927000   -209.9270          8
# 9   2020-03-27   0.021143   -209.930100   -209.9320         40
# 10  2020-04-06   0.018273   -209.818083   -209.8170         12
# 11  2020-04-06   0.031482   -209.842708   -209.8430         65
# 12  2020-04-06   0.050773   -209.873123   -209.8760        212
# 13  2020-04-06   0.042344   -209.875749   -209.8895        382
# ...

# %%
glcp_data = pd.read_csv(datadir + 'data/GLCP_data/glcp_2015.csv')
glcp_data.columns
# Out:
# Index(['Unnamed: 0', 'year', 'Hylak_id', 'centr_lat', 'centr_lon', 'continent',
#        'country', 'bsn_lvl', 'HYBAS_ID', 'mean_monthly_precip_mm',
#        'total_precip_mm', 'mean_annual_temp_k', 'pop_sum', 'seasonal_km2',
#        'permanent_km2', 'total_km2'],
#       dtype='object')

# %%
eAral_lateyears = eAral_results.loc[eAral_results['Time']> 2018000]
eAral_lateyears.plot(kind = 'scatter',y='Mean_Levels', x= 'LakeArea')
# Out:
# <Axes: xlabel='LakeArea', ylabel='Mean_Levels'>
